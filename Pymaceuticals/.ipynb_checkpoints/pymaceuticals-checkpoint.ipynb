# %% [markdown]
# ## Observations and Insights

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single dataset
mouse_df = pd.merge(mouse_metadata,study_results, on="Mouse ID" )
# Display the data table for preview
mouse_df
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# 2              35.014271                 1
# 3              34.223992                 1
# 4              32.997729                 1
# ...                  ...               ...
# 1888           63.145652                 2
# 1889           65.841013                 3
# 1890           69.176246                 4
# 1891           70.314904                 4
# 1892           73.867845                 4
#
# [1893 rows x 8 columns]

# %%
# Checking the number of mice.
mouse_df["Mouse ID"].value_counts().sum()
# Out:
# 1893

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
mouse_df["ID_Timepoint"] = mouse_df["Mouse ID"].map(str) + mouse_df["Timepoint"].map(str)

mouse_df["ID_Timepoint"]
# Out:
# 0        k4030
# 1        k4035
# 2       k40310
# 3       k40315
# 4       k40320
#          ...
# 1888    z96925
# 1889    z96930
# 1890    z96935
# 1891    z96940
# 1892    z96945
# Name: ID_Timepoint, Length: 1893, dtype: object

# %%
# Optional: Get all the data for the duplicate mouse ID. 
mouse_df["ID_Timepoint"].loc[mouse_df["ID_Timepoint"].duplicated()]
# Out:
# 909     g9890
# 911     g9895
# 913    g98910
# 915    g98915
# 917    g98920
# Name: ID_Timepoint, dtype: object

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
clean_mouse_df = mouse_df.drop_duplicates(subset=["ID_Timepoint"])
clean_mouse_df
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites ID_Timepoint
# 0              45.000000                 0        k4030
# 1              38.825898                 0        k4035
# 2              35.014271                 1       k40310
# 3              34.223992                 1       k40315
# 4              32.997729                 1       k40320
# ...                  ...               ...          ...
# 1888           63.145652                 2       z96925
# 1889           65.841013                 3       z96930
# 1890           69.176246                 4       z96935
# 1891           70.314904                 4       z96940
# 1892           73.867845                 4       z96945
#
# [1888 rows x 9 columns]

# %%
# Checking the number of mice in the clean DataFrame.
clean_mouse_df["Mouse ID"].value_counts().sum()
# Out:
# 1888

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen
group_mouse_df = clean_mouse_df.groupby("Drug Regimen")



mean_tumor_volume = group_mouse_df["Tumor Volume (mm3)"].mean()
median_tumor_volume = group_mouse_df["Tumor Volume (mm3)"].median()
variance = group_mouse_df["Tumor Volume (mm3)"].var()
std_dev = group_mouse_df["Tumor Volume (mm3)"].std()
std_err_mean = group_mouse_df["Tumor Volume (mm3)"].sem()


# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume. 
# Assemble the resulting series into a single summary dataframe.
stat_df = pd.DataFrame({"Mean Tumor Vol":mean_tumor_volume, 
                       "Median Tumor Vol":median_tumor_volume,
                       "Variance":variance,
                       "Std. Dev":std_dev,
                       "Std. Error of the Mean":std_err_mean})
stat_df
# Out:
#               Mean Tumor Vol  Median Tumor Vol   Variance  Std. Dev  \
# Drug Regimen
# Capomulin          40.675741         41.557809  24.947764  4.994774
# Ceftamin           52.591172         51.776157  39.290177  6.268188
# Infubinol          52.884795         51.820584  43.128684  6.567243
# Ketapril           55.235638         53.698743  68.553577  8.279709
# Naftisol           54.331565         52.509285  66.173479  8.134708
# Placebo            54.033581         52.288934  61.168083  7.821003
# Propriva           52.393463         50.909965  43.138803  6.568014
# Ramicane           40.216745         40.673236  23.486704  4.846308
# Stelasyn           54.233149         52.431737  59.450562  7.710419
# Zoniferol          53.236507         51.818479  48.533355  6.966589
#
#               Std. Error of the Mean
# Drug Regimen
# Capomulin                   0.329346
# Ceftamin                    0.469821
# Infubinol                   0.492236
# Ketapril                    0.603860
# Naftisol                    0.596466
# Placebo                     0.581331
# Propriva                    0.525862
# Ramicane                    0.320955
# Stelasyn                    0.573111
# Zoniferol                   0.516398

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen
# Using the aggregation method, produce the same summary statistics in a single line

group_mouse_df["Tumor Volume (mm3)"].agg([np.mean, np.median, np.var, np.std, st.sem])
# Out:
#                    mean     median        var       std       sem
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva      52.393463  50.909965  43.138803  6.568014  0.525862
# Ramicane      40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn      54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol     53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of timepoints for all mice tested for each drug regimen using Pandas.
time_bar = clean_mouse_df["Drug Regimen"].value_counts().plot(kind="bar")

#Set axes and title
time_bar.set_xlabel("Drug Regimen")
time_bar.set_ylabel("Timepoints")
time_bar.set_title("Number of Timepoints for each Drug Regimen")

time_bar

# %%
# Generate a bar plot showing the total number of timepoints for all mice tested for each drug regimen using pyplot.
count_tp = clean_mouse_df["Drug Regimen"].value_counts()

#Generate x-axis
x_axis = np.arange(len(count_tp.index))
x_axis_ticks = [value for value in x_axis]

#Generate bar graph
plt.bar(x_axis, count_tp)
plt.xticks(x_axis_ticks, count_tp.index.values, rotation=90)
plt.xlabel("Drug Regimen")
plt.ylabel("Total Timepoints")
plt.title("Total Timepoints per Drug Regimen")

plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using Pandas
sex_counts = clean_mouse_df["Sex"].value_counts()

pie_chart = sex_counts.plot(kind="pie", title="Distribution of Male vs. Female Mice", autopct="%.2f%%", startangle=90)
pie_chart.set_ylabel("")

pie_chart

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
plt.pie(sex_counts, labels=sex_counts.index.values,
        colors=["green", "yellow"], startangle=90, autopct="%.2f%%")
plt.title("Distribution of Male vs. Female Mice")
plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin

# Start by getting the last (greatest) timepoint for each mouse
gtime_df = pd.DataFrame(clean_mouse_df.groupby("Mouse ID")["Timepoint"].max())
gtime_df = gtime_df.rename(columns={"Timepoint":"Max Timepoint"})
gtime_df
# Merge this group df with the original dataframe to get the tumor volume at the last timepoint
mm_df = pd.merge(gtime_df, clean_mouse_df, on ="Mouse ID")
mm_df
# Out:
#      Mouse ID  Max Timepoint Drug Regimen     Sex  Age_months  Weight (g)  \
# 0        a203             45    Infubinol  Female          20          23
# 1        a203             45    Infubinol  Female          20          23
# 2        a203             45    Infubinol  Female          20          23
# 3        a203             45    Infubinol  Female          20          23
# 4        a203             45    Infubinol  Female          20          23
# ...       ...            ...          ...     ...         ...         ...
# 1883     z969             45     Naftisol    Male           9          30
# 1884     z969             45     Naftisol    Male           9          30
# 1885     z969             45     Naftisol    Male           9          30
# 1886     z969             45     Naftisol    Male           9          30
# 1887     z969             45     Naftisol    Male           9          30
#
#       Timepoint  Tumor Volume (mm3)  Metastatic Sites ID_Timepoint
# 0             0           45.000000                 0        a2030
# 1             5           48.508468                 0        a2035
# 2            10           51.852437                 1       a20310
# 3            15           52.777870                 1       a20315
# 4            20           55.173336                 1       a20320
# ...         ...                 ...               ...          ...
# 1883         25           63.145652                 2       z96925
# 1884         30           65.841013                 3       z96930
# 1885         35           69.176246                 4       z96935
# 1886         40           70.314904                 4       z96940
# 1887         45           73.867845                 4       z96945
#
# [1888 rows x 10 columns]

# %%
# Show values only for Capomulin, Ramicane, Infubinol, and Ceftamin
#if (merge_mouse_df["Drug Regimen"] !="Capomulin") or (merge_mouse_df["Drug Regimen"] !="Ramicane")\
 #   or (merge_mouse_df["Drug Regimen"] !="Infubinol") or (merge_mouse_df["Drug Regimen"] !="Ceftamin"):
  #  drop_df = merge_mouse_df.drop(axis=0)
    
drop_df = mm_df.drop(mm_df[(mm_df["Drug Regimen"]!="Capomulin")&(mm_df["Drug Regimen"]!="Ramicane")
                           &(mm_df["Drug Regimen"]!="Infubinol")&(mm_df["Drug Regimen"]!="Ceftamin")].index)
drop_df
# Out:
#      Mouse ID  Max Timepoint Drug Regimen     Sex  Age_months  Weight (g)  \
# 0        a203             45    Infubinol  Female          20          23
# 1        a203             45    Infubinol  Female          20          23
# 2        a203             45    Infubinol  Female          20          23
# 3        a203             45    Infubinol  Female          20          23
# 4        a203             45    Infubinol  Female          20          23
# ...       ...            ...          ...     ...         ...         ...
# 1863     z581             45    Infubinol  Female          24          25
# 1864     z581             45    Infubinol  Female          24          25
# 1865     z581             45    Infubinol  Female          24          25
# 1866     z581             45    Infubinol  Female          24          25
# 1867     z581             45    Infubinol  Female          24          25
#
#       Timepoint  Tumor Volume (mm3)  Metastatic Sites ID_Timepoint
# 0             0           45.000000                 0        a2030
# 1             5           48.508468                 0        a2035
# 2            10           51.852437                 1       a20310
# 3            15           52.777870                 1       a20315
# 4            20           55.173336                 1       a20320
# ...         ...                 ...               ...          ...
# 1863         25           54.316407                 2       z58125
# 1864         30           56.286750                 2       z58130
# 1865         35           58.628399                 3       z58135
# 1866         40           60.053740                 3       z58140
# 1867         45           62.754451                 3       z58145
#
# [814 rows x 10 columns]

# %%
# Put treatments into a list for for loop (and later for plot labels)
drug_list = ["Capomulin","Ramicane","Infubinol","Ceftamin"]

# Create empty list to fill with tumor vol data (for plotting)
tumor_vol_list = []

for drug in drug_list:
    tumor_vol = drop_df.loc[drop_df["Drug Regimen"]==drug]
    tumor_vol_list.append(tumor_vol["Tumor Volume (mm3)"].max())
# Calculate the IQR and quantitatively determine if there are any potential outliers. 
# Locate the rows which contain mice on each drug and get the tumor volumes 
# add subset    
    quartiles = tumor_vol["Tumor Volume (mm3)"].quantile([0.25,0.5,0.75])
    lower_q = quartiles[0.25]
    upper_q = quartiles[0.75]
    iqr = upper_q-lower_q
    print(f"IQR for drug regimen {drug}: {iqr}")
     
  
    # Determine outliers using upper and lower bounds
    lower_bound = lower_q-1.5*iqr
    upper_bound = upper_q+1.5*iqr
    
    outliers = drop_df.loc[(drop_df["Tumor Volume (mm3)"]>=upper_bound)|
                           (drop_df["Tumor Volume (mm3)"]<=lower_bound),["Tumor Volume (mm3)"]].count()
    print(f"the drug regimen {drug} has {outliers} outliers")
# Out:
# IQR for drug regimen Capomulin: 7.314067135000002
# the drug regimen Capomulin has Tumor Volume (mm3)    110
# dtype: int64 outliers
# IQR for drug regimen Ramicane: 8.325365415000007
# the drug regimen Ramicane has Tumor Volume (mm3)    86
# dtype: int64 outliers
# IQR for drug regimen Infubinol: 10.002090667500006
# the drug regimen Infubinol has Tumor Volume (mm3)    28
# dtype: int64 outliers
# IQR for drug regimen Ceftamin: 9.5930104575
# the drug regimen Ceftamin has Tumor Volume (mm3)    34
# dtype: int64 outliers

# %% [markdown]
# ###### Generate a box plot of the final tumor volume of each mouse across four regimens of interest

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a mouse treated with Capomulin

# %%
# Generate a scatter plot of average tumor volume vs. mouse weight for the Capomulin regimen

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen
